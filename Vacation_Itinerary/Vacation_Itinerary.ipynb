# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID        City Country  Max Temp Current Description    Lat     Lng  \
# 0        0        Gizo      SB     80.98       moderate rain  -8.10  156.84
# 1        2    Lufilufi      WS     77.00    scattered clouds -13.87 -171.60
# 2        6  Bernalillo      US     78.01           clear sky  35.05 -106.67
# 3        9     Kinkala      CG     80.60        thunderstorm  -4.36   14.76
# 4       13      Dingle      PH     76.69     overcast clouds  11.00  122.67
#
#                                Hotel Name
# 0                      Imagination Island
# 1            Leuaina Beach Resort and Spa
# 2  DoubleTree by Hilton Hotel Albuquerque
# 3                       Hotel la Vernande
# 4                             Camp Pasica

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_df
# Out:
#      City_ID        City Country  Max Temp      Current Description    Lat  \
# 0          0        Gizo      SB     80.98            moderate rain  -8.10
# 1          2    Lufilufi      WS     77.00         scattered clouds -13.87
# 2          6  Bernalillo      US     78.01                clear sky  35.05
# 3          9     Kinkala      CG     80.60             thunderstorm  -4.36
# 4         13      Dingle      PH     76.69          overcast clouds  11.00
# ..       ...         ...     ...       ...                      ...    ...
# 205      702  San Andres      CO     78.80  light intensity drizzle  12.58
# 206      705     Mahenge      TZ     75.07         scattered clouds  -8.68
# 207      706      Zaraza      VE     84.49            moderate rain   9.35
# 208      707      Corona      US     86.00                     haze  33.88
# 209      710       Pecos      US     80.60                clear sky  31.42
#
#         Lng                              Hotel Name
# ...

# %%
vacation_df.loc[(vacation_df['Country'] == "US")]
# Out:
#      City_ID            City Country  Max Temp Current Description    Lat  \
# 2          6      Bernalillo      US     78.01           clear sky  35.05
# 8         27          Duncan      US     77.00           clear sky  34.50
# 12        59           Kapaa      US     78.80       broken clouds  22.08
# 16        75            Hilo      US     77.00           clear sky  19.73
# 45       173  Elizabeth City      US     75.20           clear sky  36.29
# 61       221           Houma      US     77.00     overcast clouds  29.60
# 62       223           Avera      US     78.80     overcast clouds  33.19
# 79       272          Pierre      US     77.00           clear sky  44.37
# 83       291        Lakewood      US     79.00          few clouds  39.70
# 129      453        Havelock      US     75.99       broken clouds  34.88
# 138      495         Kahului      US     75.00           clear sky  20.89
# 160      564           Clive      US     77.00          few clouds  41.60
# ...

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df['Country'] == "US") & (vacation_df['City'] == "Salina")]
vacation_end = vacation_df.loc[(vacation_df['Country'] == "US") & (vacation_df['City'] == "Salina")]
vacation_stop1 = vacation_df.loc[(vacation_df['Country'] == "US") & (vacation_df['City'] == "Corona")]
vacation_stop2 = vacation_df.loc[(vacation_df['Country'] == "US") & (vacation_df['City'] == "Pecos")] 
vacation_stop3 = vacation_df.loc[(vacation_df['Country'] == "US") & (vacation_df['City'] == "Springfield")]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.

start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
print(start)
print(stop1)
print(stop2)
print(stop3)
print(end)
# Out:
# (38.84, -97.61)
# (33.88, -117.57)
# (31.42, -103.49)
# (37.22, -93.3)
# (38.84, -97.61)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".


fig = gmaps.figure()
US_tour = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3], travel_mode='DRIVING')
fig.add_layer(US_tour)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.

fig = gmaps.figure()
US_tour = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3], travel_mode='DRIVING', show_markers=True,
    stroke_color='red', stroke_weight=3.0, stroke_opacity=1.0)
fig.add_layer(US_tour)
fig


#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID         City Country  Max Temp Current Description    Lat     Lng  \
# 0      598       Salina      US     80.01           clear sky  38.84  -97.61
# 1      707       Corona      US     86.00                haze  33.88 -117.57
# 2      710        Pecos      US     80.60           clear sky  31.42 -103.49
# 3      597  Springfield      US     77.00           clear sky  37.22  -93.30
#
#                             Hotel Name
# 0  Holiday Inn Express & Suites Salina
# 1  Holiday Inn Express & Suites Corona
# 2                    Knights Inn Pecos
# 3     Best Western Route 66 Rail Haven

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
